# %% [markdown]
# # Histogram Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
x = np.random.randint(10,60, (50))
print(x)
# Out:
# [42 14 50 27 55 46 16 48 16 15 47 39 50 35 25 19 25 38 22 54 43 29 21 10
#  45 59 36 38 10 19 30 44 41 10 38 42 40 59 32 35 36 27 17 41 36 46 50 30
#  30 49]

# %%
# Basic Structure
No = [42, 14, 50, 27, 55, 46, 16, 48, 16, 15, 47, 39, 50, 35, 25, 19, 25,
      38, 22, 54, 43, 29, 21, 10, 45, 59, 36, 38, 10, 19, 30, 44, 41, 10, 
      38, 42, 40, 59, 32, 35, 36, 27, 17, 41, 36, 46, 50, 30, 30, 49,]
plt.hist(No)
plt.show()

# %%
No = [42, 14, 50, 27, 55, 46, 16, 48, 16, 15, 47, 39, 50, 35, 25, 19, 25,
      38, 22, 54, 43, 29, 21, 10, 45, 59, 36, 38, 10, 19, 30, 44, 41, 10, 
      38, 42, 40, 59, 32, 35, 36, 27, 17, 41, 36, 46, 50, 30, 30, 49,]

plt.hist(No, color = 'y', edgecolor='m')

plt.title("Histogram", fontsize=15)
plt.xlabel("python", fontsize=15)
plt.ylabel("No.", fontsize=15)

plt.show()

# %%
No = [42, 14, 50, 27, 55, 46, 16, 48, 16, 15, 47, 39, 50, 35, 25, 19, 25,
      38, 22, 54, 43, 29, 21, 10, 45, 59, 36, 38, 10, 19, 30, 44, 41, 10, 
      38, 42, 40, 59, 32, 35, 36, 27, 17, 41, 36, 46, 50, 30, 30, 49,]
l = [10,20,30,40,50,60]
plt.hist(No, color = 'y',bins= l, edgecolor='m')

plt.title("Histogram", fontsize=15)
plt.xlabel("python", fontsize=15)
plt.ylabel("No.", fontsize=15)

plt.show()

# %%
No = [42, 14, 50, 27, 55, 46, 16, 48, 16, 15, 47, 39, 50, 35, 25, 19, 25,
      38, 22, 54, 43, 29, 21, 10, 45, 59, 36, 38, 10, 19, 30, 44, 41, 10, 
      38, 42, 40, 59, 32, 35, 36, 27, 17, 41, 36, 46, 50, 30, 30, 49,]

plt.hist(No,"auto",(0,200), edgecolor='m')

plt.title("Histogram", fontsize=15)
plt.xlabel("python", fontsize=15)
plt.ylabel("No.", fontsize=15)

plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8516\3327374818.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(No,"auto",(0,200), edgecolor='m')

# %%
No = [42, 14, 50, 27, 55, 46, 16, 48, 16, 15, 47, 39, 50, 35, 25, 19, 25,
      38, 22, 54, 43, 29, 21, 10, 45, 59, 36, 38, 10, 19, 30, 44, 41, 10, 
      38, 42, 40, 59, 32, 35, 36, 27, 17, 41, 36, 46, 50, 30, 30, 49,]
l = [10,20,30,40,50,60]
plt.hist(No, color = 'y', edgecolor='m', cumulative = -1, align="mid", histtype="step")

plt.title("Histogram", fontsize=15)
plt.xlabel("python", fontsize=15)
plt.ylabel("No.", fontsize=15)

plt.show()

# %%
No = [42, 14, 50, 27, 55, 46, 16, 48, 16, 15, 47, 39, 50, 35, 25, 19, 25,
      38, 22, 54, 43, 29, 21, 10, 45, 59, 36, 38, 10, 19, 30, 44, 41, 10, 
      38, 42, 40, 59, 32, 35, 36, 27, 17, 41, 36, 46, 50, 30, 30, 49,]
l = [10,20,30,40,50,60]
plt.hist(No, color = 'y',bins= l, edgecolor='m', orientation="horizontal")

plt.title("Histogram", fontsize=15)
plt.xlabel("python", fontsize=15)
plt.ylabel("No.", fontsize=15)

plt.show()

# %%
No = [42, 14, 50, 27, 55, 46, 16, 48, 16, 15, 47, 39, 50, 35, 25, 19, 25,
      38, 22, 54, 43, 29, 21, 10, 45, 59, 36, 38, 10, 19, 30, 44, 41, 10, 
      38, 42, 40, 59, 32, 35, 36, 27, 17, 41, 36, 46, 50, 30, 30, 49,]
l = [10,20,30,40,50,60]
plt.hist(No, color = 'y',bins= l, edgecolor='m', rwidth= 0.8)

plt.title("Histogram", fontsize=15)
plt.xlabel("python", fontsize=15)
plt.ylabel("No.", fontsize=15)

plt.show()

# %%
No = [42, 14, 50, 27, 55, 46, 16, 48, 16, 15, 47, 39, 50, 35, 25, 19, 25,
      38, 22, 54, 43, 29, 21, 10, 45, 59, 36, 38, 10, 19, 30, 44, 41, 10, 
      38, 42, 40, 59, 32, 35, 36, 27, 17, 41, 36, 46, 50, 30, 30, 49,]
l = [10,20,30,40,50,60]
plt.hist(No, color = 'y',bins= l, edgecolor='m', log=True)

plt.title("Histogram", fontsize=15)
plt.xlabel("python", fontsize=15)
plt.ylabel("No.", fontsize=15)

plt.show()

# %%
No = [42, 14, 50, 27, 55, 46, 16, 48, 16, 15, 47, 39, 50, 35, 25, 19, 25,
      38, 22, 54, 43, 29, 21, 10, 45, 59, 36, 38, 10, 19, 30, 44, 41, 10, 
      38, 42, 40, 59, 32, 35, 36, 27, 17, 41, 36, 46, 50, 30, 30, 49,]
l = [10,20,30,40,50,60]
plt.hist(No, color = 'y',bins= l, edgecolor='m', label="Python")

plt.title("Histogram", fontsize=15)
plt.xlabel("python", fontsize=15)
plt.ylabel("No.", fontsize=15)

plt.axvline(45, color="b", label ="line")

plt.legend()
plt.grid()
plt.show()
