# %% [markdown]
# # Sub Plot

# %%
import matplotlib.pyplot as plt

# %%
# basic structure
x = [1,2,3,4,5]
y = [1,2,3,4,5]

plt.subplot(nrows, ncols, index)
plt.plot(x,y)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 x = [1,2,3,4,5]
#       3 y = [1,2,3,4,5]
# ----> 5 plt.subplot(nrows, ncols, index)
#       6 plt.plot(x,y)
#       8 plt.show()
#
# NameError: name 'nrows' is not defined

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]

plt.plot(x,y, color='r')
plt.pie([1], colors='r')

plt.show()

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]

plt.plot(x,y, color='r')
plt.pie([1], colors='r')

x1 = [10,20,30,40]
plt.pie(x1)
plt.show()

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]

plt.plot(x,y, color='r')
plt.pie([1], colors='r')

x1 = [10,20,30,40]
plt.pie(x1)

x2 = ['a','s','d','f']
y2 = [10,20,30,40]
plt.bar(x2,y2)

plt.show()

# %%
x = [1,2,3,4,5]
y = [1,2,3,4,5]
plt.subplot(2,2,1)
plt.plot(x,y, color='r')

plt.subplot(2,2,2)
plt.pie([1], colors='r')

x1 = [10,20,30,40]
plt.subplot(2,2,3)
plt.pie(x1)

x2 = ['a','s','d','f']
y2 = [10,20,30,40]
plt.subplot(2,2,4)
plt.bar(x2,y2)

plt.show()
